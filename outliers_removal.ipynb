# %%
# %pip install mysql-connector-python
# %pip install pandas
# %pip install scikit-learn
# %pip install numpy
#%pip install dtale
#%pip install scipy
import mysql.connector
import pandas as pd
import dtale
import numpy as np

# %%
#database connection
connection = mysql.connector.connect(
            host="localhost",
            user="root",
            password="1234",
            database =  "pszbooks3"
        )

# %%
query = 'select * from books;'
df = pd.read_sql(query, con = connection)
# Out:
# C:\Users\SSS\AppData\Local\Temp\ipykernel_17416\2017408121.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
df.head(3)
# Out:
#    idBook                      title publisher    year  number_of_pages  \
# 0       3  Grof Monte Kristo – I tom    laguna  2024.0            768.0
# 1       6              Zenova savest    laguna  2024.0            450.0
# 2       7          Velika očekivanja    laguna  2024.0            520.0
#
#   cover_binding  format_width  format_height  \
# 0          tvrd          13.0           20.0
# 1          tvrd          13.0           20.0
# 2          tvrd          13.0           20.0
#
#                                          description   price
# 0  Ljubav. Izdaja. Nevini zatočenik. Opasno bekst...  1799.0
# 1  „Veliki moderni roman o komično-patetičnoj ilu...  1199.0
# 2  Čuvena priča o siročetu koje je postalo džentl...  1499.0

# %%
from sklearn.impute import SimpleImputer #za podatke koji fale
from sklearn.compose import ColumnTransformer #za kodiranje kategorickih podataka na diskretne vrednosti
from sklearn.preprocessing import LabelEncoder, OneHotEncoder 
from sklearn.model_selection import train_test_split #za deljenje na training i test split
from sklearn.preprocessing import StandardScaler #za feature scaling
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# In order to identify outliers we will use the triple standard deviation method and see how our continuous features agree with a normal distribution, looking at a distance of 3 or 5 standard deviations from the mean on either side as the cutoff.

# %%
from scipy.stats import norm

plt.hist(df.number_of_pages, bins=1000, density=True)
plt.xlabel('Broj stranica')
plt.ylabel('Broj podataka')
plt.xlim(0, 2000)

range_for_normal_distribution = np.arange(df.number_of_pages.min(), df.number_of_pages.max(), 0.1)
plt.plot(range_for_normal_distribution, norm.pdf(range_for_normal_distribution, df.number_of_pages.mean(), df.number_of_pages.std()))

plt.show()

# %%
up_limit = df.number_of_pages.mean() + 5*df.number_of_pages.std()
up_limit
# Out:
# 1422.6332550993054

# %%
down_limit = df.number_of_pages.mean() - 5*df.number_of_pages.std()
down_limit
# Out:
# -828.6963665778778

# %% [markdown]
# We can see the potential outliers below:

# %%
df[(df.number_of_pages > up_limit)]
# Out:
#        idBook                                              title  \
# 1533     5478                               Komplet - Fantastika
# 1818     5907                   Komplet - Redovi koji iznenađuju
# 1887     6081                           Komplet - Ninova nagrada
# 1889     6089                            Komplet - Romani godine
# 1890     6090                               Komplet – True Crime
# 1893     6095                     Komplet - Heroine svog vremena
# 1911     6133                              Komplet – Zlatno runo
# 2230     6753                      Sabrana dela Mira Vuksanovića
# 2568     7293                              Vreme smrti - Komplet
# 5279    11748                     SVESKE LEONARDA DA VINČIJA 1-2
# 5368    11924      SABRANA DELA PETRA II PETROVIĆA NJEGOŠA I-VII
# 5940    12678                VELIKI REČNIK STRANIH REČI I IZRAZA
# 1911   Oživljavajući nam porodicu Njegovan, u istorij...   8999.0
# 2230   Sabrana dela akademika Mira Vuksanovića u deve...  12999.0
# 2568   Delo koje s neprocenjivom snagom svedoči o tom...   5699.0
# 5279   Pretpostavlja se da je Leonardo da Vinči za ži...   3465.0
# 5368   Najpotpunije izdanje Njegoševih dela u sedam t...   5920.0
# 5940   VELIKI REČNIK STRANIH RECI I IZRAZA, na 1.600 ...   8067.0
# 6755   Komentar Zakona o izvršenju i obezbeđenju pred...   3960.0
# 8316   Knjiga pesama Gojka Đoga Vunena vremena u izda...   3960.0
# 10245  Novo izdanje knjige Ivora Hortona Od početka.....   1980.0
# 10326  Rečnike karakteriše okrenutost korisniku, pode...   8550.0
# 10386  Univerzalni, lako upotrebljiv dvosmerni rečnik...   2772.0
# 10404  Ovaj englesko-srpski enciklopedijski rečnik na...   6875.0
# 10415  Na ukupno 1493 strane, u formatu 24 x 17 cm, V...   7920.0
# 11486  Po rečima Grigorija Ostrogorskog, Uspenski je,...   6600.0
# 15530  Frekvencijski rečnik srpskog jezika rezultat j...  12375.0
# 15769  Mario Alinei, profesor emeritus Univerziteta u...   5310.0

# %%
df[df.idBook == 17966]
# Out:
#        idBook                                   title    publisher    year  \
# 10404   17966  ENGLESKO-SRPSKI ENCIKLOPEDIJSKI REČNIK  ik prometej  2009.0
#
#        number_of_pages cover_binding  format_width  format_height  \
# 10404          15987.0          None          24.0           24.0
#
#                                              description   price
# 10404  Ovaj englesko-srpski enciklopedijski rečnik na...  6875.0
# 2024-06-13 03:24:48,701 - INFO     - Executing shutdown due to inactivity...
# 2024-06-13 03:24:52,789 - INFO     - Executing shutdown...
# 2024-06-13 03:24:52,805 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %% [markdown]
# We can see that this row certainly represents an outlier, while the other books marked as outliers above will not be outliers.

# %%
df.drop(df[df['idBook'] == 17966].index, inplace=True)

# %% [markdown]
# After deletion:

# %%
plt.hist(df.number_of_pages, bins=1000, rwidth=0.8, density=True)
plt.xlabel('Broj stranica')
plt.ylabel('Broj podataka')
plt.xlim(0, 1500)

range_for_normal_distribution = np.arange(df.number_of_pages.min(), df.number_of_pages.max())
plt.plot(range_for_normal_distribution, norm.pdf(range_for_normal_distribution, df.number_of_pages.mean(), df.number_of_pages.std()))

plt.show()

# %%
plt.hist(df.format_width, bins=80, rwidth=0.8)
plt.xlabel('Fomat-sirina')
plt.ylabel('Broj podataka')
plt.xlim(0, 40)
plt.show()

# %%
plt.hist(df.format_width, bins=300, rwidth=0.8, density=True)
plt.xlabel('Fomat-sirina')
plt.ylabel('Broj podataka')
plt.xlim(10, 40)

range_for_normal_distribution = np.arange(df.format_width.min(), df.format_width.max(), 0.1)
plt.plot(range_for_normal_distribution, norm.pdf(range_for_normal_distribution, df.format_width.mean(), df.format_width.std()))

plt.show()

up_limit = df.format_width.mean() + 3*df.format_width.std()
print(up_limit)
down_limit = df.format_width.mean() - 3*df.format_width.std()
print(down_limit)

df[(df.format_width > up_limit) | (df.format_width < down_limit)]
# Out:
# 33.58341513362713
# 6.374512040764426
#        idBook                                              title  \
# 3112     8662                                      Knjiga kućica
# 3314     9088                             VELIKA KNJIGA O SPORTU
# 3375     9157                                       DINOSAURIJUM
# 3720     9581         100 NAJLEPŠIH NACIONALNIH PARKOVA NA SVETU
# 3859     9741                            SREBRNI LETAČ: PARABOLA
# 4015     9907                       KONAN DIVLJI MAČ SIMERIJE 10
# 4016     9908  ĐORĐE LOBAČEV: SABRANA DELA. KNJ. 2, PRINCEZA ...
# 4032     9927                                 LENS 4 (1958-1960)
# 4070     9970                                 LENS 3 (1957-1958)
# 4082     9982  ĐORĐE LOBAČEV - SABRANA DELA 1 - PLAVA PUSTOLO...
# 4140    10044                                    MUZEJ UMETNOSTI
# 4377    10475                 VALENTINA 1 BIOGRAFIJA JEDNOG LIKA
# 4469    10581                                   SLEJN ROGATI BOG
# 4851    10993                            EL TOPOVI SINOVI 1 KAIN
# 4852    10994                            ELRIK 1 RUBINSKI PRESTO
# 4854    10996                                    ELRIK 2 OLUJNIK
# 4867    11009                            KARAVAĐO 1 PALETA I MAČ
# 5022    11227                     IKONE STILA SRBIJE XX-XXI VEKA
# 5197    11597  IZGUBLJENI GRADOVI -  TRAGOM DREVNIH CIVILIZACIJA
# 5465    12118                        KONAN DIVLJI MAČ SIMERIJE 8
# 5491    12147                        KONAN DIVLJI MAČ SIMERIJE 9
# 5525    12183                                  THE LONG TOMORROW
# 5666    12342                        SVEŽA RIBA I MORSKI PLODOVI
# 5763    12450     SAMUDARIPEN ROMA U NEZAVISNOJ DRŽAVI HRVATSKOJ
# 5824    12536                                  BOŽANSTVENE TORTE
# 5931    12666                                     VLADARI SRBIJE
# 6156    12907                             OVE PRIČE NA IGRU LIČE
# 6233    12988                                  MIKELANĐELO : 500
# 6333    13098                     PRVI RAT MODERNE SRBIJE (1876)
# 6535    13311                                     PRAZNA PLANETA
# 7120    14009  THE HOLY MONASTERY OF CHILANDAR THE SERBIAN EM...
# 7428    14335                         ZABORAVLJENA ISTORIJA SRBA
# 8028    15026               JASENOVAC - AUSCHWITZ OF THE BALKANS
# 8524    15642  ALOJZIJE STEPINAC, USTAŠKI VIKAR - POKRSTI SE ...
# 8526    15645  USTAŠKO KONAČNO REŠENJE PRE NACISTIČKOG KONAČN...
# 8614    15761  ITALIJANSKA KUHINJA - RECEPTI SA POTPISOM STAR...
# 10273   17705            SRPSKI NARODNI KALENDAR ZA 2016. GODINU
# 11616   19756                                     SVI SE BROJIMO
# 11825   20097                    ŠTA SU PANDE MALE MAMI OBEĆALE?
# 12540   21037                      MALI KONJANIK U PAČIJOJ ŠKOLI
# 13450   22035                                       TRI PRINCEZE
# 14890   23782                                          MAMA I JA
# 14952   23845                                          BOTANIKUM
# 15865        data status  2018.0            664.0          tvrd           2.0
#
#        format_height                                        description  \
# 3112            30.0  Istraži, čitaj, uči i igraj se! Ovo je jedna d...
# 3314            40.0  U ovoj knjizi će ljubitelji sporta otkriti pre...
# 3375            38.0  Ovaj "muzej" prikazuje život na Zemlji kakav n...
# 3720            35.0  Putovanje preko pet kontinenata. Ova knjiga će...
# 3859            34.0  Galaktus je prevratio čovečanstvo u svoje sled...
# 4015            35.0  Živi mrtvaci, podzemni tuneli, đavolske legije...
# 4016            35.0                                               None
# 4032            35.0                                               None
# 4070            35.0                                               None
# 4082            35.0  Reč izdavača S velikim ponosom vam predstavlja...
# 4140            42.0  „Zašto kupiti običnu knjigu o umetnosti kada m...
# 4377            35.0  Kultni serijal italijanskog strip-autora Gvida...
# 4469            35.0                                               None
# 4851            35.0  Nastavak svog kultnog filma "El Topo" iz 1970,...
# 4852            35.0  Imao sam prilike da vidim nekoliko raskošnih v...
# 4854            35.0                                               None
# 4867            35.0  Mikelanđelo Merizi da Karavađo, zvani Karavađo...
# 5022            34.0  "U antologiji Ikona stila nijedna ličnost ne n...
# 5197            35.0  Najlepši drevni gradovi koji su, prema izboru ...
# 5465            35.0  U osmoj knjizi Divljeg mača Simerije čeka vas ...
# 5491            35.0  ...Miruj i ne traži rukom balčak, Konane od Si...
# 5525            34.0  The Long Tomorrow je, kako smo mogli da saznam...
# 5666            24.0  Za 2 kupljene knjige, druga jeftinija knjiga j...
# 5763            37.0  ”Reč je o prvoj studiji o stradanju Roma na pr...
# 5824            34.0  Odrasla sam u Vojvodini, ravnici plodne Panons...
# 5931            39.0  NAPOMENA: KNJIGA NIJE NA MAJSKOJ AKCIJI.Za sve...
# 6156            38.7  Ovaj radni materijal sadrži raznovrsne podstic...
# 6233            34.0  Mikelanđelo Buonaroti – genijalan stvaralac, i...
# 6333            34.0  Knjiga je posvećena 145. godišnjici početka Sr...
# 6535            51.0  Veliki presudan događaj XXI veka – jedan od on...
# 7120            34.0  Ova celovita monografija po svom konceptu pred...
# 7428             2.0  Knjiga Ivana Miladinovića je vanredno zanimlji...
# 8028            39.0  Ova knjiga nije uperena ni protiv jednog narod...
# 8524            38.0  U trećem tomu, objavljenom pod nazivom „Alojzi...
# 8526            38.0  Drugi tom trilogije „Ustaško konačno rešenje p...
# 8614            35.0  Otkrijte najveća dostignuća italijanske kulina...
# 10273           12.0  Srpski narodni kalendar predstavlja skup pravi...
# 11616           34.0  Ura za razlike među ljudima! Svi smo mi važni ...
# 11825           37.0  Visoko u planinama, među oblacima koji nebom p...
# 12540           34.0  Ilustrovane izabrane pesme Jovana Jovanovića Z...
# 13450           62.0  Da li ste nekada glumili u predstavi? Jeste li...
# 14890           38.0  Jedna stranica je za mamu, a druga za dete, a ...
# 14952           38.0  Dobro došli u Botanikum. Ovaj muzej je uvek ot...
# 15141           35.0  Slika-knjiga Trg tišine i pored nastojanja da ...
# 15233           35.0  Autor, Vojislav Puškar, poznati istraživač, na...
# 15240           38.0  Dobro došli u Animalijum. Ovaj muzej je uvek o...
# 15865           28.0  Neprevaziđen prikaz anatomije ljudskog tela u ...
#
#          price
# 3112     799.0
# 3314    2241.0
# 3375    3356.0
# 3720    3231.0
# 3859    2241.0
# 4015    2646.0
# 4016    1706.0
# 4032    1544.0
# 4070    1544.0
# 4082    1978.0
# 4140   23760.0
# 4377    1791.0
# 4469    2970.0
# 4851    1530.0
# 4852    1485.0
# 4854    1485.0
# 4867    1535.0
# 5022    8100.0
# 5197    7641.0
# 5465    2655.0
# 5491    2655.0
# 5525     891.0
# 5666    2241.0
# 5763   12870.0
# 5824    1350.0
# 5931   35991.0
# 6156     990.0
# 6233   17910.0
# 6333    2970.0
# 6535     792.0
# 7120    3168.0
# 7428     743.0
# 8028   11880.0
# 8524   11316.0
# 8526   11316.0
# 8614    4948.0
# 10273    297.0
# 11616   1395.0
# 11825   1238.0
# 12540   1980.0
# 13450    675.0
# 14890    989.0
# 14952   3356.0
# 15141   4455.0
# 15233   5316.0
# 15240   3356.0
# 15865   8513.0

# %% [markdown]
# Looking at the site, we can see that indeed some of these books were entered with the wrong dimensions! We will delete them from the database.

# %%
plt.hist(df.format_height, bins=200, rwidth=0.8)
plt.xlabel('Fomat-duzina')
plt.ylabel('Broj podataka')
plt.xlim(0, 40)
plt.show()

# %%
plt.hist(df.format_height, bins=300, rwidth=0.8, density=True)
plt.xlabel('Fomat-duzina')
plt.ylabel('Broj podataka')
plt.xlim(10, 40)

range_for_normal_distribution = np.arange(df.format_height.min(), df.format_height.max())
plt.plot(range_for_normal_distribution, norm.pdf(range_for_normal_distribution, df.format_height.mean(), df.format_height.std()))

plt.show()

up_limit = df.format_height.mean() + 5*df.format_height.std()
print(up_limit)
down_limit = df.format_height.mean() - 5*df.format_height.std()
print(down_limit)

df[(df.format_height > up_limit) | (df.format_height < down_limit)]
# Out:
# 37.55195862306964
# 5.490289048714899
#        idBook                                              title  \
# 2747     7632                   Mali princ – ilustrovano izdanje
# 3136     8728              Ko je viši, ti ili tigar? (visinomer)
# 3314     9088                             VELIKA KNJIGA O SPORTU
# 3375     9157                                       DINOSAURIJUM
# 4139    10044                                    MUZEJ UMETNOSTI
# 5926    12666                                     VLADARI SRBIJE
# 6151    12907                             OVE PRIČE NA IGRU LIČE
# 6530    13311                                     PRAZNA PLANETA
# 6829    13646                   SOVA - VELIKI PORODIČNI LEKSIKON
# 8022    15026               JASENOVAC - AUSCHWITZ OF THE BALKANS
# 8518    15642  ALOJZIJE STEPINAC, USTAŠKI VIKAR - POKRSTI SE ...
# 8520    15645  USTAŠKO KONAČNO REŠENJE PRE NACISTIČKOG KONAČN...
# 10911   18896                                    ANĐELI IZOBILJA
# 13442   22035                                       TRI PRINCEZE
# 14882   23782                                          MAMA I JA
# 14944   23845                                          BOTANIKUM
# 15232   24203                                         ANIMALIJUM
#
#                publisher    year  number_of_pages cover_binding  format_width  \
# 2747              laguna  2023.0             80.0          tvrd          24.5
# 3136              laguna  2020.0             10.0           mek          25.0
# 3314   vulkan izdavaštvo  2022.0              NaN          tvrd          40.0
# 3375         data status  2023.0              NaN          tvrd          38.0
# 4139         data status  2017.0            992.0          tvrd          42.0
# 5926    mladinska knjiga  2013.0            384.0          tvrd          39.0
# 6151    kreativni centar  2021.0              NaN          broš          38.7
# 6530    službeni glasnik  2019.0            257.0          broš          51.0
# 6829    mladinska knjiga  2011.0           1214.0          tvrd          21.0
# 8022       knjiga komerc  2018.0            710.0          tvrd          39.0
# 8518       knjiga komerc  2020.0            878.0          None          38.0
# 8520       knjiga komerc  2020.0            928.0          None          38.0
# 10911      čigoja štampa     NaN            178.0           mek          14.0
# 13442   kreativni centar  2021.0              NaN          broš          62.0
# 14882  vulkan izdavaštvo  2020.0            192.0          broš          38.0
# 14944        data status  2017.0              NaN          tvrd          38.0
# 15232        data status  2017.0              NaN          tvrd          38.0
#
#        format_height                                        description  \
# 2747            40.0  Mali princ je čudesna poetska priča koja se de...
# 3136           150.0  Visinomer sa nalepnicama i zanimljivim činjeni...
# 3314            40.0  U ovoj knjizi će ljubitelji sporta otkriti pre...
# 3375            38.0  Ovaj "muzej" prikazuje život na Zemlji kakav n...
# 4139            42.0  „Zašto kupiti običnu knjigu o umetnosti kada m...
# 5926            39.0  NAPOMENA: KNJIGA NIJE NA MAJSKOJ AKCIJI.Za sve...
# 6151            38.7  Ovaj radni materijal sadrži raznovrsne podstic...
# 6530            51.0  Veliki presudan događaj XXI veka – jedan od on...
# 6829            39.0  Za 2 kupljene knjige, druga jeftinija knjiga j...
# 8022            39.0  Ova knjiga nije uperena ni protiv jednog narod...
# 8518            38.0  U trećem tomu, objavljenom pod nazivom „Alojzi...
# 8520            38.0  Drugi tom trilogije „Ustaško konačno rešenje p...
# 10911            1.0  Anđeli izobilja je knjiga koja opisuje kako Ne...
# 13442           62.0  Da li ste nekada glumili u predstavi? Jeste li...
# 14882           38.0  Jedna stranica je za mamu, a druga za dete, a ...
# 14944           38.0  Dobro došli u Botanikum. Ovaj muzej je uvek ot...
# 15232           38.0  Dobro došli u Animalijum. Ovaj muzej je uvek o...
#
#          price
# 2747    1899.0
# 3136     799.0
# 3314    2241.0
# 3375    3356.0
# 4139   23760.0
# 5926   35991.0
# 6151     990.0
# 6530     792.0
# 6829   11691.0
# 8022   11880.0
# 8518   11316.0
# 8520   11316.0
# 10911    792.0
# 13442    675.0
# 14882    989.0
# 14944   3356.0
# 15232   3356.0

# %%
plt.hist(df.year, bins=2000, rwidth=0.8)
plt.xlabel('Godina izdavanja')
plt.ylabel('Broj podataka')
plt.xlim(1990, 2030)
plt.show()
